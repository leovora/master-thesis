# %%
import sys
sys.path.append('../scr')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data.load_data import load_data_from_csv
from trade.trading_strategy import moving_average_strategy
from trade.backtest import simulate_trades_with_allocation
from utils import *

tickers = ['GOOGL', 'AMZN', 'AAPL', 'PEP', 'JNJ', 'PFE', 'MRK', 'ABBV', 'PG', 'KO',
           'WMT', 'JPM', 'BAC', 'GS', 'V', 'XOM', 'CVX', 'COP', 'BP', 'BA',
           'MMM', 'HON', 'GE', 'T', 'VZ', 'TMUS', 'HSY', 'DUK', 'SO', 'EXC', 'AEP',
           'AMT', 'PLD', 'SPG', 'BHP', 'RIO', 'VALE', 'FCX']
start_date = '2010-01-01'
end_date = '2023-10-23'
sequence_length = 50
window_sizes = [50, 40, 30]

# %%
predictions, actuals = get_predictions(tickers, start_date, end_date, sequence_length, folder_path='models')

trading_signals = moving_average_strategy(predictions)

portfolio_returns = simulate_trades_with_allocation(predictions, actuals, trading_signals, initial_capital=100000, allocation_percentage=0.1, slippage_rate=0.02, transaction_cost=0.005)
# Out:
# Processing GOOGL...
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2026-04-24 16:24:31.282922: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-04-24 16:24:31.283068: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2026-04-24 16:24:34.572917: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2026-04-24 16:24:34.958285: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:35.163404: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:36.550080: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 85ms/step
# Processing AMZN...
# 2026-04-24 16:24:41.273855: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:41.417821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:42.703508: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 77ms/step
# Processing AAPL...
# 2026-04-24 16:24:47.226556: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:47.377582: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:48.710591: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 133ms/step
# Processing PEP...
# 2026-04-24 16:24:54.253059: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:54.401122: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:24:55.725714: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 91ms/step
# Processing JNJ...
# 2026-04-24 16:25:00.415337: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:00.568993: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:01.885911: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 83ms/step
# Processing PFE...
# 2026-04-24 16:25:06.744115: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:06.895368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:08.201773: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 76ms/step
# Processing MRK...
# 2026-04-24 16:25:12.479118: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:12.630616: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:13.887668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 77ms/step
# Processing ABBV...
# 2026-04-24 16:25:18.642534: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:18.787116: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:20.059404: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 17/17 [==============================] - 5s 106ms/step
# Processing PG...
# 2026-04-24 16:25:25.316056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:25.464419: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:26.802021: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 85ms/step
# Processing KO...
# 2026-04-24 16:25:31.724668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:31.875930: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:33.180390: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 83ms/step
# Processing WMT...
# 2026-04-24 16:25:37.961947: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:38.351915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:39.756083: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 77ms/step
# Processing JPM...
# 2026-04-24 16:25:44.450822: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:44.596874: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:46.030617: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 80ms/step
# Processing BAC...
# 2026-04-24 16:25:50.687152: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:50.836009: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:52.167202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 78ms/step
# Processing GS...
# 2026-04-24 16:25:56.749585: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:56.910799: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:25:58.351185: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 78ms/step
# Processing V...
# 2026-04-24 16:26:02.813163: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:02.958751: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:04.399057: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 81ms/step
# Processing XOM...
# 2026-04-24 16:26:08.897544: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:09.043834: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:10.411963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 82ms/step
# Processing CVX...
# 2026-04-24 16:26:15.366509: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:15.515073: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:17.258373: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 81ms/step
# Processing COP...
# 2026-04-24 16:26:21.871145: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:22.015118: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:23.300403: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 96ms/step
# Processing BP...
# 2026-04-24 16:26:28.884525: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:29.028900: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:30.395022: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 85ms/step
# Processing BA...
# 2026-04-24 16:26:35.380796: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:35.528051: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:37.081755: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 83ms/step
# Processing MMM...
# 2026-04-24 16:26:41.858603: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:42.004842: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:43.365685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 81ms/step
# Processing HON...
# 2026-04-24 16:26:47.903833: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:48.049300: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:49.506026: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 85ms/step
# Processing GE...
# 2026-04-24 16:26:54.733122: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:54.883351: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:26:56.356683: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 80ms/step
# Processing T...
# 2026-04-24 16:27:00.936572: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:01.090510: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:02.469981: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 129ms/step
# Processing VZ...
# 2026-04-24 16:27:08.408551: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:08.554593: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:10.087335: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 88ms/step
# Processing TMUS...
# 2026-04-24 16:27:15.304405: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:15.469288: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:17.333387: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 91ms/step
# Processing HSY...
# 2026-04-24 16:27:22.766444: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:22.920254: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:24.365693: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 81ms/step
# Processing DUK...
# 2026-04-24 16:27:29.128762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:29.294626: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:30.721789: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 104ms/step
# Processing SO...
# 2026-04-24 16:27:36.296571: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:36.445941: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:37.862952: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 79ms/step
# Processing EXC...
# 2026-04-24 16:27:42.392398: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:42.541702: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:43.939504: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 85ms/step
# Processing AEP...
# 2026-04-24 16:27:48.612516: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:48.761027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:50.193201: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 81ms/step
# Processing AMT...
# 2026-04-24 16:27:55.020451: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:55.166112: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:27:56.537899: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 81ms/step
# Processing PLD...
# 2026-04-24 16:28:01.161423: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:01.318477: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:02.850993: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 86ms/step
# Processing SPG...
# 2026-04-24 16:28:07.561027: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:07.706970: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:09.074064: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 7s 172ms/step
# Processing BHP...
# 2026-04-24 16:28:16.082454: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:16.226488: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:17.655154: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 5s 80ms/step
# Processing RIO...
# 2026-04-24 16:28:22.642846: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:22.818466: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:24.275046: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 90ms/step
# Processing VALE...
# 2026-04-24 16:28:29.450775: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:29.615337: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:31.277203: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 87ms/step
# Processing FCX...
# 2026-04-24 16:28:36.248703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:36.397246: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2026-04-24 16:28:37.803075: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 6s 99ms/step

# %%
targeted_dates = [
    "2021-11-15", "2021-12-02", "2022-01-24", "2022-02-08",
    "2023-04-17", "2023-05-10", "2023-06-13", "2023-07-11"
]

scenarios = {
    "scenario_1": 0.0,   # Same as previous price
    "scenario_2": 0.005, # 0.5% higher
    "scenario_3": -0.005 # 0.5% lower
}

def get_targeted_indices_for_ticker(ticker, start_date, end_date, sequence_length, targeted_dates):
    _, _, X_test, _, _, _, x_min, _ = preprocess_data(ticker, start_date, end_date, sequence_length)
    
    full_dates_range = pd.date_range(start=start_date, end=end_date)
    test_dates_range = full_dates_range[-X_test.shape[0]:]  
    
    targeted_indices = []
    for date in targeted_dates:
        date = pd.Timestamp(date)  
        idx = np.where(test_dates_range == date)[0]
        if idx.size != 0:  
            targeted_indices.append(idx[0])
    
    return targeted_indices

def perform_scenario_attack(ticker, start_date, end_date, sequence_length, attack_indices, drop_percentage, folder_path="models"):
    model_path = os.path.join(folder_path, f"{ticker}_model.h5")
    model = load_model(model_path)

    _, _, X_test, y_test, y_min, y_max, x_min, x_max = preprocess_data(ticker, start_date, end_date, sequence_length)

    attacked_X_test = X_test.copy()
    y_actual = y_test * (y_max - y_min) + y_min

    for attack_day in attack_indices:
        previous_price = y_actual[attack_day-1]
        if drop_percentage == 0.0:
            new_price = previous_price
        else:
            new_price = previous_price * (1 + drop_percentage)
        attacked_X_test[attack_day, -1, 3] = (new_price - y_min) / (y_max - y_min)

    y_pred = model.predict(attacked_X_test)
    y_pred_rescaled = y_pred * (y_max - y_min) + y_min

    predictions = {ticker: y_pred_rescaled.flatten()}
    actuals = {ticker: y_actual.flatten()}

    return predictions, actuals

def calculate_cumulative_returns(predictions, actuals):
    returns = (predictions / actuals) - 1
    cumulative_returns = np.cumsum(returns)
    return cumulative_returns

def analyze_scenarios_for_targeted_days(tickers, start_date, end_date, sequence_length, targeted_indices):
    baseline_predictions, baseline_actuals = get_predictions(tickers, start_date, end_date, sequence_length)
    
    baseline_cumulative_returns = calculate_cumulative_returns(baseline_predictions['GOOGL'], baseline_actuals['GOOGL'])
    
    results = { "scenario_1": [], "scenario_2": [], "scenario_3": [] }

    for attack_day in targeted_indices:
        for scenario_name, drop_percentage in scenarios.items():
            predictions_after_attack, actuals_after_attack = perform_scenario_attack('GOOGL', start_date, end_date, sequence_length, [attack_day], drop_percentage)
            
            combined_predictions = baseline_predictions.copy()
            combined_predictions['GOOGL'] = predictions_after_attack['GOOGL']
            
            cumulative_returns_after_attack = calculate_cumulative_returns(combined_predictions['GOOGL'], baseline_actuals['GOOGL'])
            
            delta_cr = cumulative_returns_after_attack - baseline_cumulative_returns
            delta_percentage = (delta_cr / 0.20) * 100
            
            results[scenario_name].append((attack_day, delta_cr[-1], delta_percentage[-1]))

    if not os.path.exists('results'):
        os.makedirs('results')

    with open('results/concea_scenarios.txt', 'w') as f:
        for scenario, data in results.items():
            f.write(f"\nResults for {scenario}:\n")
            for attack_day, delta_cr, delta_percentage in data:
                f.write(f"Day {attack_day}: CR change: {delta_cr}, Delta %: {delta_percentage}\n")

    for scenario, data in results.items():
        print(f"\nResults for {scenario}:")
        for attack_day, delta_cr, delta_percentage in data:
            print(f"Day {attack_day}: CR change: {delta_cr}, Delta %: {delta_percentage}")

targeted_indices = get_targeted_indices_for_ticker('GOOGL', start_date, end_date, sequence_length, targeted_dates)

analyze_scenarios_for_targeted_days(tickers, start_date, end_date, sequence_length, targeted_indices)
# Out:
# Processing GOOGL...
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
#
# 22/22 [==============================] - 6s 83ms/step
# Processing AMZN...
# 22/22 [==============================] - 5s 75ms/step
# Processing AAPL...
# 22/22 [==============================] - 5s 75ms/step
# Processing PEP...
# 22/22 [==============================] - 5s 78ms/step
# Processing JNJ...
# 22/22 [==============================] - 5s 103ms/step
# Processing PFE...
# 22/22 [==============================] - 5s 79ms/step
# Processing MRK...
# 22/22 [==============================] - 5s 79ms/step
# Processing ABBV...
# 17/17 [==============================] - 5s 104ms/step
# Processing PG...
# 22/22 [==============================] - 5s 79ms/step
# Processing KO...
# 22/22 [==============================] - 5s 77ms/step
# Processing WMT...
# 22/22 [==============================] - 5s 106ms/step
# Processing JPM...
# 22/22 [==============================] - 5s 82ms/step
# Processing BAC...
# 22/22 [==============================] - 5s 77ms/step
# Processing GS...
# 22/22 [==============================] - 6s 96ms/step
# Processing V...
# 22/22 [==============================] - 5s 92ms/step
# Processing XOM...
# 22/22 [==============================] - 5s 78ms/step
# Processing CVX...
# 22/22 [==============================] - 5s 77ms/step
# Processing COP...
# 22/22 [==============================] - 5s 77ms/step
# Processing BP...
# 22/22 [==============================] - 5s 79ms/step
# Processing BA...
# 22/22 [==============================] - 5s 81ms/step
# Processing MMM...
# 22/22 [==============================] - 5s 79ms/step
# Processing HON...
# 22/22 [==============================] - 6s 114ms/step
# Processing GE...
# 22/22 [==============================] - 5s 81ms/step
# Processing T...
# 22/22 [==============================] - 5s 85ms/step
# Processing VZ...
# 22/22 [==============================] - 5s 85ms/step
# Processing TMUS...
# 22/22 [==============================] - 5s 85ms/step
# Processing HSY...
# 22/22 [==============================] - 5s 78ms/step
# Processing DUK...
# 22/22 [==============================] - 5s 80ms/step
# Processing SO...
# 22/22 [==============================] - 5s 80ms/step
# Processing EXC...
# 22/22 [==============================] - 5s 79ms/step
# Processing AEP...
# 22/22 [==============================] - 5s 78ms/step
# Processing AMT...
# 22/22 [==============================] - 5s 81ms/step
# Processing PLD...
# 22/22 [==============================] - 5s 85ms/step
# Processing SPG...
# 22/22 [==============================] - 5s 81ms/step
# Processing BHP...
# 22/22 [==============================] - 5s 83ms/step
# Processing RIO...
# 22/22 [==============================] - 5s 81ms/step
# Processing VALE...
# 22/22 [==============================] - 6s 85ms/step
# Processing FCX...
# 22/22 [==============================] - 6s 83ms/step
# 22/22 [==============================] - 6s 110ms/step
# 22/22 [==============================] - 6s 86ms/step
# 22/22 [==============================] - 6s 106ms/step
# 22/22 [==============================] - 5s 84ms/step
# 22/22 [==============================] - 6s 92ms/step
# 22/22 [==============================] - 6s 87ms/step
# 22/22 [==============================] - 6s 96ms/step
# 22/22 [==============================] - 6s 83ms/step
# 22/22 [==============================] - 5s 82ms/step
# 22/22 [==============================] - 5s 80ms/step
# 22/22 [==============================] - 5s 88ms/step
# 22/22 [==============================] - 5s 86ms/step
# 22/22 [==============================] - 6s 86ms/step
# 22/22 [==============================] - 5s 85ms/step
# 22/22 [==============================] - 5s 85ms/step
# 22/22 [==============================] - 6s 104ms/step
# 22/22 [==============================] - 6s 89ms/step
# 22/22 [==============================] - 6s 86ms/step
#
# Results for scenario_1:
# Day 47: CR change: 0.004275876268813761, Delta %: 2.1379381344068804
# Day 62: CR change: -0.00800637594726794, Delta %: -4.00318797363397
# Day 495: CR change: 0.009089131912048742, Delta %: 4.544565956024371
# Day 518: CR change: -0.0007108470658110377, Delta %: -0.35542353290551887
# Day 552: CR change: -0.0031059798830597174, Delta %: -1.5529899415298587
# Day 580: CR change: 0.008974233927602882, Delta %: 4.487116963801441
#
# Results for scenario_2:
# Day 47: CR change: 0.006674956500305029, Delta %: 3.3374782501525146
# Day 62: CR change: -0.005606991112195203, Delta %: -2.8034955560976016
# Day 495: CR change: 0.011281347310749368, Delta %: 5.640673655374684
# Day 518: CR change: 0.0016168618103691301, Delta %: 0.8084309051845651
# Day 552: CR change: -0.0008172915228144007, Delta %: -0.4086457614072003
# Day 580: CR change: 0.011425575217252515, Delta %: 5.7127876086262575
#
# Results for scenario_3:
# Day 47: CR change: 0.0018772072847283994, Delta %: 0.9386036423641997
# Day 62: CR change: -0.010405038511173359, Delta %: -5.2025192555866795
# Day 495: CR change: 0.006897308905308819, Delta %: 3.4486544526544094
# Day 518: CR change: -0.0030383020378081937, Delta %: -1.5191510189040969
# Day 552: CR change: -0.005394095408867372, Delta %: -2.697047704433686
# Day 580: CR change: 0.006523331991424186, Delta %: 3.261665995712093

# %%
# Define the targeted dates and scenarios
targeted_dates = [
    "2021-11-15", "2021-12-02", "2022-01-24", "2022-02-08",
    "2023-04-17", "2023-05-10", "2023-06-13", "2023-07-11"
]

scenarios = {
    "scenario_1": -0.10,  # 10% drop
    "scenario_2": -0.025, # 2.5% drop
    "scenario_3": -0.01   # 1% drop
}

def get_targeted_indices_for_ticker(ticker, start_date, end_date, sequence_length, targeted_dates):
    _, _, X_test, _, _, _, x_min, _ = preprocess_data(ticker, start_date, end_date, sequence_length)
    
    full_dates_range = pd.date_range(start=start_date, end=end_date)
    test_dates_range = full_dates_range[-X_test.shape[0]:]  
    
    targeted_indices = []
    for date in targeted_dates:
        date = pd.Timestamp(date)  
        idx = np.where(test_dates_range == date)[0]
        if idx.size != 0:  
            targeted_indices.append(idx[0])
    
    return targeted_indices

def perform_scenario_attack(ticker, start_date, end_date, sequence_length, attack_indices, drop_percentage, folder_path="models"):
    model_path = os.path.join(folder_path, f"{ticker}_model.h5")
    model = load_model(model_path)

    _, _, X_test, y_test, y_min, y_max, x_min, x_max = preprocess_data(ticker, start_date, end_date, sequence_length)

    attacked_X_test = X_test.copy()
    y_actual = y_test * (y_max - y_min) + y_min

    for attack_day in attack_indices:
        previous_price = y_actual[attack_day-1]
        if drop_percentage == 0.0:
            new_price = previous_price
        else:
            new_price = previous_price * (1 + drop_percentage)
        attacked_X_test[attack_day, -1, 3] = (new_price - y_min) / (y_max - y_min)

    y_pred = model.predict(attacked_X_test)
    y_pred_rescaled = y_pred * (y_max - y_min) + y_min

    predictions = {ticker: y_pred_rescaled.flatten()}
    actuals = {ticker: y_actual.flatten()}

    return predictions, actuals

def calculate_cumulative_returns(predictions, actuals):
    returns = (predictions / actuals) - 1
    cumulative_returns = np.cumsum(returns)
    return cumulative_returns

def analyze_scenarios_for_targeted_days(tickers, start_date, end_date, sequence_length, targeted_indices):
    baseline_predictions, baseline_actuals = get_predictions(tickers, start_date, end_date, sequence_length)
    
    baseline_cumulative_returns = calculate_cumulative_returns(baseline_predictions['GOOGL'], baseline_actuals['GOOGL'])
    
    results = { "scenario_1": [], "scenario_2": [], "scenario_3": [] }

    for attack_day in targeted_indices:
        for scenario_name, drop_percentage in scenarios.items():
            predictions_after_attack, actuals_after_attack = perform_scenario_attack('GOOGL', start_date, end_date, sequence_length, [attack_day], drop_percentage)
            
            combined_predictions = baseline_predictions.copy()
            combined_predictions['GOOGL'] = predictions_after_attack['GOOGL']
            
            cumulative_returns_after_attack = calculate_cumulative_returns(combined_predictions['GOOGL'], baseline_actuals['GOOGL'])
            
            delta_cr = cumulative_returns_after_attack - baseline_cumulative_returns
            delta_percentage = (delta_cr / 0.20) * 100
            
            results[scenario_name].append((attack_day, delta_cr[-1], delta_percentage[-1]))

    if not os.path.exists('results'):
        os.makedirs('results')

    with open('results/overestimate_scenarios.txt', 'w') as f:
        for scenario, data in results.items():
            f.write(f"\nResults for {scenario}:\n")
            for attack_day, delta_cr, delta_percentage in data:
                f.write(f"Day {attack_day}: CR change: {delta_cr}, Delta %: {delta_percentage}\n")

    for scenario, data in results.items():
        print(f"\nResults for {scenario}:")
        for attack_day, delta_cr, delta_percentage in data:
            print(f"Day {attack_day}: CR change: {delta_cr}, Delta %: {delta_percentage}")

targeted_indices = get_targeted_indices_for_ticker('GOOGL', start_date, end_date, sequence_length, targeted_dates)

analyze_scenarios_for_targeted_days(tickers, start_date, end_date, sequence_length, targeted_indices)
# Out:
# Processing GOOGL...
# 22/22 [==============================] - 2s 63ms/step
# Processing AMZN...
# 22/22 [==============================] - 2s 54ms/step
# Processing AAPL...
# 22/22 [==============================] - 2s 61ms/step
# Processing PEP...
# 22/22 [==============================] - 2s 54ms/step
# Processing JNJ...
# 22/22 [==============================] - 2s 63ms/step
# Processing PFE...
# 22/22 [==============================] - 2s 48ms/step
# Processing MRK...
# 22/22 [==============================] - 2s 43ms/step
# Processing ABBV...
# 17/17 [==============================] - 1s 49ms/step
# Processing PG...
# 22/22 [==============================] - 2s 53ms/step
# Processing KO...
# 22/22 [==============================] - 2s 42ms/step
# Processing WMT...
# 22/22 [==============================] - 2s 46ms/step
# Processing JPM...
# 22/22 [==============================] - 2s 54ms/step
# Processing BAC...
# 22/22 [==============================] - 2s 42ms/step
# Processing GS...
# 22/22 [==============================] - 2s 83ms/step
# Processing V...
# 22/22 [==============================] - 2s 73ms/step
# Processing XOM...
# 22/22 [==============================] - 3s 85ms/step
# Processing CVX...
# 22/22 [==============================] - 2s 75ms/step
# Processing COP...
# 22/22 [==============================] - 2s 80ms/step
# Processing BP...
# 22/22 [==============================] - 2s 79ms/step
# Processing BA...
# 22/22 [==============================] - 2s 71ms/step
# Processing MMM...
# 22/22 [==============================] - 2s 62ms/step
# Processing HON...
# 22/22 [==============================] - 2s 66ms/step
# Processing GE...
# 22/22 [==============================] - 3s 89ms/step
# Processing T...
# 22/22 [==============================] - 2s 76ms/step
# Processing VZ...
# 22/22 [==============================] - 3s 87ms/step
# Processing TMUS...
# 22/22 [==============================] - 2s 84ms/step
# Processing HSY...
# 22/22 [==============================] - 3s 87ms/step
# Processing DUK...
# 22/22 [==============================] - 2s 67ms/step
# Processing SO...
# 22/22 [==============================] - 2s 83ms/step
# Processing EXC...
# 22/22 [==============================] - 2s 58ms/step
# Processing AEP...
# 22/22 [==============================] - 2s 66ms/step
# Processing AMT...
# 22/22 [==============================] - 2s 50ms/step
# Processing PLD...
# 22/22 [==============================] - 2s 45ms/step
# Processing SPG...
# 22/22 [==============================] - 2s 54ms/step
# Processing BHP...
# 22/22 [==============================] - 2s 76ms/step
# Processing RIO...
# 22/22 [==============================] - 2s 79ms/step
# Processing VALE...
# 22/22 [==============================] - 2s 84ms/step
# Processing FCX...
# 22/22 [==============================] - 2s 79ms/step
# 22/22 [==============================] - 2s 72ms/step
# 22/22 [==============================] - 3s 85ms/step
# 22/22 [==============================] - 1s 45ms/step
# 22/22 [==============================] - 2s 72ms/step
# 22/22 [==============================] - 2s 76ms/step
# 22/22 [==============================] - 2s 75ms/step
# 22/22 [==============================] - 2s 68ms/step
# 22/22 [==============================] - 2s 60ms/step
# 22/22 [==============================] - 2s 72ms/step
# 22/22 [==============================] - 2s 68ms/step
# 22/22 [==============================] - 2s 75ms/step
# 22/22 [==============================] - 3s 87ms/step
# 22/22 [==============================] - 2s 85ms/step
# 22/22 [==============================] - 3s 105ms/step
# 22/22 [==============================] - 2s 75ms/step
# 22/22 [==============================] - 2s 81ms/step
# 22/22 [==============================] - 2s 73ms/step
# 22/22 [==============================] - 2s 72ms/step
#
# Results for scenario_1:
# Day 47: CR change: -0.04360156956241923, Delta %: -21.800784781209614
# Day 62: CR change: -0.055881795375228194, Delta %: -27.940897687614097
# Day 495: CR change: -0.034654358138048735, Delta %: -17.327179069024368
# Day 518: CR change: -0.04715560154028253, Delta %: -23.577800770141266
# Day 552: CR change: -0.0487718791156766, Delta %: -24.3859395578383
# Day 580: CR change: -0.03995185812114954, Delta %: -19.97592906057477
#
# Results for scenario_2:
# Day 47: CR change: -0.00771253312804987, Delta %: -3.856266564024935
# Day 62: CR change: -0.019995169191915352, Delta %: -9.997584595957676
# Day 495: CR change: -0.0018651620833836091, Delta %: -0.9325810416918046
# Day 518: CR change: -0.012342428113370829, Delta %: -6.171214056685415
# Day 552: CR change: -0.014541797797257061, Delta %: -7.270898898628531
# Day 580: CR change: -0.0032756098909274556, Delta %: -1.6378049454637278
#
# Results for scenario_3:
# Day 47: CR change: -0.0005209260260556903, Delta %: -0.26046301302784514
# Day 62: CR change: -0.012803334599098548, Delta %: -6.401667299549274
# Day 495: CR change: 0.004705986926666128, Delta %: 2.352993463333064
# Day 518: CR change: -0.005365086970392952, Delta %: -2.682543485196476
# Day 552: CR change: -0.0076817343006396754, Delta %: -3.8408671503198377
# Day 580: CR change: 0.004072911515457633, Delta %: 2.0364557577288167
